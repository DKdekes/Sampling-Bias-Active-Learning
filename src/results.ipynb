# %%
import matplotlib.pyplot as plt
import pickle
import numpy as np

# %%
with open('../logs/Bert_dbpedia_entropy_init_train_0.01_delete_0.000625_acqiters_39_seed_0_run_0/acc_Test.pkl', 'rb') as f:
    ent_acc = pickle.load(f)

with open('../logs/Bert_dbpedia_random_init_train_0.01_delete_0.000625_acqiters_39_seed_0_run_0/acc_Test.pkl', 'rb') as f:
    rand_acc = pickle.load(f)

# %%
rand_acc.x
# Out:
# [0.005,
#  0.01,
#  0.015,
#  0.02,
#  0.025,
#  0.030000000000000002,
#  0.034999999999999996,
#  0.04,
#  0.045,
#  0.049999999999999996,
#  0.055,
#  0.06,
#  0.065,
#  0.07,
#  0.07500000000000001,
#  0.08,
#  0.085,
#  0.09000000000000001,
#  0.095,
#  0.1,
#  0.10500000000000001,
#  0.11,
#  0.115,
#  0.12000000000000001,
#  0.125,
#  0.13,
#  0.135,
#  0.14,
#  0.14500000000000002,
#  0.15,
#  0.155,
#  0.16,
#  0.165,
#  0.17,
#  0.17500000000000002,
#  0.18000000000000002,
#  0.185,
#  0.19,
#  0.195]

# %%
plt.plot(ent_acc.x, ent_acc.y, label='entropy sampling')
plt.plot(rand_acc.x, rand_acc.y, label='random sampling')
plt.legend()
plt.xlabel('percentage of train set')
plt.ylabel('test accuracy')
plt.savefig('here')
